# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline
#the important thing for drawing plots in JN

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
plt.plot(x, y, 'r')
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('String Title Here')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x, y, 'r--') 
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-');

# %%
fig = plt.figure()

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) 

axes.plot(x, y, 'b')
axes.set_xlabel('Set X Label') 
axes.set_ylabel('Set y Label')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) 
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) 

axes1.plot(x, y, 'b')
axes1.set_xlabel('X_label_axes2')
axes1.set_ylabel('Y_label_axes2')
axes1.set_title('Larger plot')

axes2.plot(y, x, 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Smaller plot');

# %%
fig,axis = plt.subplots(nrows = 1, ncols = 2)
for current_ax in axis:
    current_ax.plot(x,y)

# %%
fig,axis = plt.subplots(nrows = 1, ncols = 2)
axis[0].plot(x,y)
axis[0].set_title('First Title')
axis[1].plot(y,x)
axis[1].set_title('Second Title')

plt.tight_layout() #to avoid overlapping of several figures

# %%
fig = plt.figure(figsize = (3,2))
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2, label = 'X Squared')
ax.plot(x,x**3, label = 'X Cubed')
ax.legend(loc = 0)

# %%
fig.savefig('my_picture')

# %%
noise = 0.1
n_train = 150  

def f(x):
    return x**3

def generate(n_samples, noise):
    X = np.linspace(-1.9, 1.9, 150)
    y = X**3 + np.random.normal(0.0, noise, n_samples)
    return X, y

generate(n_samples=n_train, noise=noise)

plt.figure()
plt.scatter(X, y, c="b")
plt.xlim([-2, 2])
plt.show()plt.xlim([-5, 5])
