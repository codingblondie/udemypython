# %%
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips = sb.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sb.distplot(tips['total_bill'])

# %%
sb.distplot(tips['total_bill'],kde=False,bins=30)

# %%
sb.jointplot(x='total_bill',y='tip',data=tips,kind='scatter')

# %%
sb.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
sb.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %%
sb.pairplot(tips)

# %%
sb.pairplot(tips,hue='smoker',palette='coolwarm')

# %%
sb.rugplot(tips['total_bill'])

# %%
sb.barplot(x='sex',y='total_bill',data=tips)

# %%
sb.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)

# %%
sb.countplot(x='smoker',data=tips)

# %%
sb.boxplot(x="day", y="total_bill", data=tips,palette='rainbow')

# %%
sb.boxplot(data=tips,palette='rainbow',orient='h')

# %%
sb.boxplot(x="day", y="total_bill", hue="smoker",data=tips, palette="coolwarm")

# %%
sb.violinplot(x="day", y="total_bill", data=tips,palette='rainbow')

# %%
sb.violinplot(x="day", y="total_bill", data=tips,hue='sex',palette='Set1')

# %%
sb.violinplot(x="day", y="total_bill", data=tips,hue='sex',split=True,palette='Set1')

# %%
sb.stripplot(x="day", y="total_bill", data=tips)

# %%
sb.stripplot(x="day", y="total_bill", data=tips,jitter=True)

# %%
sb.stripplot(x="day", y="total_bill", data=tips,jitter=True,hue='sex',palette='Set1')

# %%
sb.stripplot(x="day", y="total_bill", data=tips,jitter=True,hue='sex',palette='Set1',split=True)
# Out:
# /home/anzhelika/.local/lib/python3.6/site-packages/seaborn/categorical.py:2775: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sb.swarmplot(x="day", y="total_bill", data=tips)

# %%
sb.swarmplot(x="day", y="total_bill",hue='sex',data=tips, palette="Set1", split=True)
# Out:
# /home/anzhelika/.local/lib/python3.6/site-packages/seaborn/categorical.py:2974: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sb.violinplot(x="tip", y="day", data=tips,palette='rainbow')
sb.swarmplot(x="tip", y="day", data=tips,color='black',size=3)

# %%
sb.factorplot(x='sex',y='total_bill',data=tips,kind='bar')
# Out:
# /home/anzhelika/.local/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
flights = sb.load_dataset('flights')

# %%
tips = sb.load_dataset('tips')

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sb.heatmap(tips.corr())

# %%
sb.heatmap(tips.corr(),cmap='coolwarm',annot=True)

# %%
flights.pivot_table(values='passengers',index='month',columns='year')
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
pvflights = flights.pivot_table(values='passengers',index='month',columns='year')
sb.heatmap(pvflights)

# %%
sb.heatmap(pvflights,cmap='magma',linecolor='white',linewidths=1)

# %%
sb.clustermap(pvflights)

# %%
sb.clustermap(pvflights,cmap='coolwarm',standard_scale=1)

# %%
iris = sb.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sb.PairGrid(iris)

# %%
g = sb.PairGrid(iris)
g.map(plt.scatter)

# %%
g = sb.PairGrid(iris)
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sb.kdeplot)

# %%
sb.pairplot(iris)

# %%
sb.pairplot(iris,hue='species',palette='rainbow')

# %%
tips = sb.load_dataset('tips')

# %%
g = sb.FacetGrid(tips, col="time",  row="smoker")
g = g.map(plt.hist, "total_bill")

# %%
g = sb.FacetGrid(tips, col="time",  row="smoker",hue='sex')
g = g.map(plt.scatter, "total_bill", "tip").add_legend()

# %%
g = sb.JointGrid(x="total_bill", y="tip", data=tips)
g = g.plot(sb.regplot, sb.distplot)

# %%
sb.lmplot(x='total_bill',y='tip',data=tips)

# %%
sb.lmplot(x='total_bill',y='tip',data=tips,hue='sex')

# %%
sb.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='coolwarm')

# %%
sb.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='coolwarm',
           markers=['o','v'],scatter_kws={'s':100})

# %%
sb.lmplot(x='total_bill',y='tip',data=tips,col='sex')

# %%
sb.lmplot(x="total_bill", y="tip", row="sex", col="time",data=tips)

# %%
sb.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',palette='coolwarm')

# %%
sb.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',palette='coolwarm',
          aspect=0.6,size=8)
# Out:
# /home/anzhelika/.local/lib/python3.6/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sb.countplot(x='sex',data=tips)

# %%
sb.set_style('white')
sb.countplot(x='sex',data=tips)

# %%
sb.set_style('ticks')
sb.countplot(x='sex',data=tips,palette='deep')

# %%
sb.countplot(x='sex',data=tips)
sb.despine()

# %%
sb.countplot(x='sex',data=tips)
sb.despine(left=True)

# %%
plt.figure(figsize=(12,3))
sb.countplot(x='sex',data=tips)

# %%
sb.lmplot(x='total_bill',y='tip',size=2,aspect=4,data=tips)

# %%
sb.set_context('poster',font_scale=4)
sb.countplot(x='sex',data=tips,palette='coolwarm')
